# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Nikhil Poojari\OneDrive\Desktop\Portfolio projects\Customer Churn Analysis\customer_churn_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 5000 non-null   object
#  1   age                         5000 non-null   int64
#  2   gender                      5000 non-null   object
#  3   city                        5000 non-null   object
#  4   tenure_months               5000 non-null   int64
#  5   plan_type                   5000 non-null   object
#  6   monthly_charges             5000 non-null   int64
#  7   payment_method              5000 non-null   object
#  8   auto_renew                  5000 non-null   int64
#  9   last_payment_status         5000 non-null   object
#  10  avg_sessions_per_week       5000 non-null   float64
#  11  avg_session_duration        5000 non-null   float64
#  12  days_since_last_login       5000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                   0
# age                           0
# gender                        0
# city                          0
# tenure_months                 0
# plan_type                     0
# monthly_charges               0
# payment_method                0
# auto_renew                    0
# last_payment_status           0
# avg_sessions_per_week         0
# avg_session_duration          0
# days_since_last_login         0
# feature_usage_score           0
# support_tickets               0
# avg_ticket_resolution_days    0
# complaints_flag               0
# churn                         0
# dtype: int64

# %%
features = ["avg_session_duration","avg_sessions_per_week","feature_usage_score","support_tickets","gender","plan_type","last_payment_status"]

X = df[features]
y = df["churn"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
categorical_cols = ["gender", "plan_type", "last_payment_status"]

le = LabelEncoder()

for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# %%
# Logistic Regression
lr_model = LogisticRegression(max_iter=1000)
categorical_cols = X_train.select_dtypes(include='object').columns

X_train_encoded = pd.get_dummies(X_train, columns=categorical_cols, drop_first=True)
X_test_encoded = pd.get_dummies(X_test, columns=categorical_cols, drop_first=True)
